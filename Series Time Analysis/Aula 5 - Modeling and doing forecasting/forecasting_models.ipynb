# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf

# %% [markdown]
# ## Code

# %%
# tendencia - para onde meu dado vai conforme o tempo passa (evolucao temporal) - direcao
# sazonalidade - entender como funcionam as oscilacoes da serie temporal - recorrencia das oscilacoes
# residuo - o que sobra do sinal - que não traz informação revelante

# %%
df_path = "https://raw.githubusercontent.com/carlosfab/datasets/master/electricity_consumption/Electric_Production.csv"

# %%
df = pd.read_csv(df_path)

df.head()
# Out:
#          DATE    Value
# 0  01-01-1985  72.5052
# 1  02-01-1985  70.6720
# 2  03-01-1985  62.4502
# 3  04-01-1985  57.4714
# 4  05-01-1985  55.3151

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    397 non-null    object
#  1   Value   397 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ KB

# %%
df.index = pd.to_datetime(df.DATE,format = "%m-%d-%Y")

# %%
df.drop("DATE", inplace=True, axis=1)

# %%
df.head()
# Out:
#               Value
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
df.loc['1985-05-01']
# Out:
# Value    55.3151
# Name: 1985-05-01 00:00:00, dtype: float64

# %%
plt.plot(df.index, df.Value)
plt.show()

# %%
results = seasonal_decompose(df)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize = (15,10))

results.observed.plot(ax=ax1)
results.trend.plot(ax=ax2)
results.seasonal.plot(ax=ax3)
results.resid.plot(ax=ax4)

plt.tight_layout()

# %% [markdown]
# **ADF (Augmented Dickey-Fuller)**
#
#     H0 -> Hipótese Nula (não é estacionária)
#     H1 -> Hipótese Alternativa (rejeição da hipótese nula: é estacionária)
#
# - p value < 0.05 (5%), então rejeitamos H0 com um nível de confiança de 95%

# %%
# Estacionaria ou não estacionaria - estacionaria: média, variancia e co-variancia são constantes
from statsmodels.tsa.stattools import adfuller

# %%
X = df.Value.values
result = adfuller(X)

print("Teste ADF")
print(f"Teste Estatístico: {result[0]}")
print(f"P-Value: {result[1]}")
print(f"Valores críticos: ")

for key, value in result[4].items():
    print(f"\t{key}: {value}")
    
print("\n")
p_value = result[1]
if p_value < 0.05:
    print("Rejeitamos a H0 (hipótese nula).")
    print("A série é estacionária!")
else:
    print("H0: Hipótese nula.")
    print("A série não é estacionária!")
# Out:
# Teste ADF
# Teste Estatístico: -2.256990350047241
# P-Value: 0.18621469116586903
# Valores críticos:
# 	1%: -3.4476305904172904
# 	5%: -2.869155980820355
# 	10%: -2.570827146203181
#
#
# H0: Hipótese nula.
# A série não é estacionária!

# %%
ma = df.rolling(12).mean()


f, ax = plt.subplots()
df.plot(ax=ax, legend=False)
ma.plot(ax=ax, legend=False, color='r')
plt.tight_layout()

# %%
ma[:15]
# Out:
#                 Value
# DATE
# 1985-01-01        NaN
# 1985-02-01        NaN
# 1985-03-01        NaN
# 1985-04-01        NaN
# 1985-05-01        NaN
# 1985-06-01        NaN
# 1985-07-01        NaN
# 1985-08-01        NaN
# 1985-09-01        NaN
# 1985-10-01        NaN
# 1985-11-01        NaN
# 1985-12-01  62.165667
# 1986-01-01  62.232375
# 1986-02-01  62.008617
# 1986-03-01  61.989608

# %%
df_log = np.log(df)
ma_log = df_log.rolling(12).mean()

ma_log_refat = ma_log.rename(columns={'Value':'Média Móvel (12 meses)'})

f, ax = plt.subplots()
df_log.plot(ax=ax, legend=False)
ma_log_refat.plot(ax=ax, legend=True, color='r')

plt.tight_layout()
plt.title("Plotando a média móvel (12 meses)")
plt.show()

# %%
df_sub = (df_log - ma_log).dropna()

ma_sub = df_sub.rolling(12).mean()
std = df_sub.rolling(12).std()

ma_sub.rename(columns={'Value':'Média Móvel (12 meses)'}, inplace=True)
std.rename(columns={'Value':'Desvio Padrão (12 meses)'}, inplace=True)

f, ax = plt.subplots()
df_sub.plot(ax=ax, legend=False)
ma_sub.plot(ax=ax, legend=True, color='r')
std.plot(ax=ax, legend=True, color='g')

plt.tight_layout()
plt.title("Subtraindo a média móvel dos valores")
plt.show()

# %%
X_s = df_sub.Value.values
result_s = adfuller(X_s)

print("Teste ADF")
print(f"Teste Estatístico: {result_s[0]}")
print(f"P-Value: {result_s[1]}")
print(f"Valores críticos: ")

for key, value in result_s[4].items():
    print(f"\t{key}: {value}")
    

print("\n")
p_value = result_s[1]
if p_value < 0.05:
    print("Rejeitamos a H0 (hipótese nula).")
    print("A série é estacionária!")
else:
    print("H0: Hipótese nula.")
    print("A série não é estacionária!")
# Out:
# Teste ADF
# Teste Estatístico: -5.211586185365429
# P-Value: 8.325639759946488e-06
# Valores críticos:
# 	1%: -3.448147967010838
# 	5%: -2.8693833397824413
# 	10%: -2.5709483564645725
#
#
# Rejeitamos a H0 (hipótese nula).
# A série é estacionária!

# %%
df_diff  = df_sub.diff(1) # primeira derivada
ma_diff = df_diff.rolling(12).mean()
std_diff = df_diff.rolling(12).std()

ma_diff.rename(columns={'Value':'Média Móvel (12 meses)'}, inplace=True)
std_diff.rename(columns={'Value':'Desvio Padrão (12 meses)'}, inplace=True)

f, ax = plt.subplots()
df_diff.plot(ax=ax, legend=False)
ma_diff.plot(ax=ax, legend=True, color='r')
std_diff.plot(ax=ax, legend=True, color='g')

plt.tight_layout()
plt.title("Realizando 1° Derivação")
plt.show()

# %%
X_diff = df_diff.Value.dropna().values
result_diff = adfuller(X_diff)

print("Teste ADF")
print(f"Teste Estatístico: {result_diff[0]}")
print(f"P-Value: {result_diff[1]}")
print(f"Valores críticos: ")

for key, value in result_diff[4].items():
    print(f"\t{key}: {value}")
    

print("\n")
p_value = result_diff[1]
if p_value < 0.05:
    print("Rejeitamos a H0 (hipótese nula).")
    print("A série é estacionária!")
else:
    print("H0: Hipótese nula.")
    print("A série não é estacionária!")
# Out:
# Teste ADF
# Teste Estatístico: -7.651129568145197
# P-Value: 1.78812673543548e-11
# Valores críticos:
# 	1%: -3.448294490928673
# 	5%: -2.869447722240253
# 	10%: -2.570982681065269
#
#
# Rejeitamos a H0 (hipótese nula).
# A série é estacionária!

# %% [markdown]
# ARIMA - AR: Autoregressivo, I: Integrado, MA: Moving Average
#
# A (x,y,z) -> ACF, PACF

# %%
lag_acf = acf(df_diff.dropna(), nlags=25)
lag_pacf = pacf(df_diff.dropna(), nlags=25)

# %%
# 5% ACF

# 1.96/sqrt(N-d) -> N - numero de pontos do df e d eh o numero de vezes que nós diferenciamos o dataframe
sns.set_theme()
plt.plot(lag_acf)

plt.axhline(y= (-1.96/(np.sqrt(len(df_diff) -1))), linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y= 0, linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y= (+1.96/(np.sqrt(len(df_diff) -1))), linestyle='--', color='gray', linewidth=0.7)

plt.title("ACF")
plt.show()

plt.plot(lag_pacf)

plt.axhline(y= (-1.96/(np.sqrt(len(df_diff) -1))), linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y= 0, linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y= (+1.96/(np.sqrt(len(df_diff) -1))), linestyle='--', color='gray', linewidth=0.7)

plt.title("PACF")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df.Value)
plot_pacf(df.Value)
plt.show()

# %%
new_df = pd.read_csv('bases/train.csv', index_col='id', parse_dates=['date'])

# %%
new_df['store_nbr'].unique()

# %%
df_1 = new_df.loc[new_df['store_nbr'] == 1, ['date','family','sales']]
df_1 = df_1.rename(columns={'date':'ds','sales':'y','family':'unique_id'})
df_1

# %%
#! pip install statsforecast
# Out:
# Collecting statsforecast
#   Downloading statsforecast-1.7.5-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 715 kB/s eta 0:00:01
# Collecting coreforecast>=0.0.9
#   Downloading coreforecast-0.0.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (223 kB)
#      |████████████████████████████████| 223 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.21.6 in /home/jessimoura/.local/lib/python3.8/site-packages (from statsforecast) (1.24.3)
# Requirement already satisfied: scipy>=1.7.3 in /home/jessimoura/.local/lib/python3.8/site-packages (from statsforecast) (1.10.1)
# Requirement already satisfied: threadpoolctl in /home/jessimoura/.local/lib/python3.8/site-packages (from statsforecast) (3.5.0)
# Requirement already satisfied: pandas>=1.3.5 in /home/jessimoura/.local/lib/python3.8/site-packages (from statsforecast) (2.0.2)
# Collecting numba>=0.55.0
#   Downloading numba-0.58.1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 149 kB/s eta 0:00:01
# Requirement already satisfied: statsmodels>=0.13.2 in /home/jessimoura/.local/lib/python3.8/site-packages (from statsforecast) (0.14.1)
# Collecting utilsforecast>=0.1.4
#   Downloading utilsforecast-0.1.11-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 226 kB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 132 kB/s eta 0:00:01
# Collecting fugue>=0.8.1
#   Downloading fugue-0.9.1-py3-none-any.whl (278 kB)
#      |████████████████████████████████| 278 kB 233 kB/s eta 0:00:01
# Collecting cloudpickle
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: importlib_resources; python_version < "3.10" in /home/jessimoura/.local/lib/python3.8/site-packages (from coreforecast>=0.0.9->statsforecast) (6.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jessimoura/.local/lib/python3.8/site-packages (from pandas>=1.3.5->statsforecast) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/jessimoura/.local/lib/python3.8/site-packages (from pandas>=1.3.5->statsforecast) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/jessimoura/.local/lib/python3.8/site-packages (from pandas>=1.3.5->statsforecast) (2023.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in /home/jessimoura/.local/lib/python3.8/site-packages (from numba>=0.55.0->statsforecast) (6.8.0)
# Collecting llvmlite<0.42,>=0.41.0dev0
#   Downloading llvmlite-0.41.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
#      |████████████████████████████████| 43.6 MB 561 kB/s eta 0:00:01
# Requirement already satisfied: packaging>=21.3 in /home/jessimoura/.local/lib/python3.8/site-packages (from statsmodels>=0.13.2->statsforecast) (23.1)
# Requirement already satisfied: patsy>=0.5.4 in /home/jessimoura/.local/lib/python3.8/site-packages (from statsmodels>=0.13.2->statsforecast) (0.5.6)
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting triad>=0.9.7
#   Downloading triad-0.9.7-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 282 kB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/jessimoura/.local/lib/python3.8/site-packages (from importlib_resources; python_version < "3.10"->coreforecast>=0.0.9->statsforecast) (3.18.1)
# Requirement already satisfied: six>=1.5 in /home/jessimoura/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->statsforecast) (1.16.0)
# Collecting fsspec>=2022.5.0
#   Downloading fsspec-2024.6.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 258 kB/s eta 0:00:01
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 263 kB/s eta 0:00:01
# Requirement already satisfied: pyarrow>=6.0.1 in /home/jessimoura/.local/lib/python3.8/site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast) (12.0.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast) (45.2.0)
# Collecting appdirs~=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: coreforecast, llvmlite, numba, utilsforecast, tqdm, fsspec, appdirs, fs, triad, adagio, fugue, cloudpickle, statsforecast
# Successfully installed adagio-0.2.4 appdirs-1.4.4 cloudpickle-3.0.0 coreforecast-0.0.10 fs-2.4.16 fsspec-2024.6.0 fugue-0.9.1 llvmlite-0.41.1 numba-0.58.1 statsforecast-1.7.5 tqdm-4.66.4 triad-0.9.7 utilsforecast-0.1.11
